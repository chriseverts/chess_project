# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# ^^^ pyforest auto-imports - don't write above this line
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.reset_option("display.max_rows", "display.max_columns")

# %%
# reading csv files
data1 = pd.read_csv('chess_players.csv')
data2 = pd.read_csv('int_chess_stats.csv')
  
# using merge function by setting how='right'. Country is the primary key
df = pd.merge(data1, data2,
                   on='Country',
                   how='left')
  
df
# Out:
#         Unnamed: 0_x  Country Rank                       Name  \
# 0                  0             1      Mirzaad, S.wahabuddin
# 1                  1             2              Rahmani, Asef
# 2                  2             3        Sarwari, Hamidullah
# 3                  3             4          Sakhawaty, Sepehr
# 4                  4             5  Jamshedy, Mohammad Ismail
# ...              ...           ...                        ...
# 175376        175353           155         Mafukidze, Ruvimbo
# 175377        175354           156           Nyarenda Miranda
# 175378        175355           157           Gandiwa, Ellagia
# 175379        175356           158            ASHANTI KUVIMBA
# 175380        175357           159           Munyurwa, Seraph
#
#                    Title      Country    FIDE  Age  K-factor  Unnamed: 0_y  \
# 0                     FM  Afghanistan  1999.0   35        20           132
# 1       unranked/unrated  Afghanistan  1871.0   49        20           132
# 2       unranked/unrated  Afghanistan  1866.0   33        20           132
# 3       unranked/unrated  Afghanistan  1846.0   19        20           132
# 4       unranked/unrated  Afghanistan  1790.0   78        20           132
# ...                  ...          ...     ...  ...       ...           ...
# 175376  unranked/unrated     Zimbabwe  1056.0   24        40            96
# 175377  unranked/unrated     Zimbabwe  1045.0   15        40            96
# 175378  unranked/unrated     Zimbabwe  1029.0   34        40            96
# 175379  unranked/unrated     Zimbabwe  1028.0   18        40            96
# 175380  unranked/unrated     Zimbabwe  1014.0   22        40            96
#
#           #  Flag  Num Players  Women  % of Women  FIDE Average  GMs  IMs  \
# 0       133   NaN           78      1        1.28          1650    0    0
# 1       133   NaN           78      1        1.28          1650    0    0
# 2       133   NaN           78      1        1.28          1650    0    0
# 3       133   NaN           78      1        1.28          1650    0    0
# 4       133   NaN           78      1        1.28          1650    0    0
# ...     ...   ...          ...    ...         ...           ...  ...  ...
# 175376   97   NaN          287     66       23.00          1617    0    4
# 175377   97   NaN          287     66       23.00          1617    0    4
# 175378   97   NaN          287     66       23.00          1617    0    4
# 175379   97   NaN          287     66       23.00          1617    0    4
# 175380   97   NaN          287     66       23.00          1617    0    4
#
#         FMs  WGMs  WIMs  WFMs  Age Avg
# 0         5     0     0     0       40
# 1         5     0     0     0       40
# 2         5     0     0     0       40
# 3         5     0     0     0       40
# 4         5     0     0     0       40
# ...     ...   ...   ...   ...      ...
# 175376    0     0     0     0       25
# 175377    0     0     0     0       25
# 175378    0     0     0     0       25
# 175379    0     0     0     0       25
# 175380    0     0     0     0       25
#
# [175381 rows x 22 columns]

# %% [markdown]
# - assign the blank column with some ID label. That is your natural key
# - Surrogate keys should be used. Most likely Country which is in both tables should be the primary key
# - May need to look at both csv files seperately to determine hiearchy and keys

# %%
# Set index to Country
df = df.set_index('Country')
df
# Out:
#              Unnamed: 0_x  Country Rank                       Name  \
# Country
# Afghanistan             0             1      Mirzaad, S.wahabuddin
# Afghanistan             1             2              Rahmani, Asef
# Afghanistan             2             3        Sarwari, Hamidullah
# Afghanistan             3             4          Sakhawaty, Sepehr
# Afghanistan             4             5  Jamshedy, Mohammad Ismail
# ...                   ...           ...                        ...
# Zimbabwe           175353           155         Mafukidze, Ruvimbo
# Zimbabwe           175354           156           Nyarenda Miranda
# Zimbabwe           175355           157           Gandiwa, Ellagia
# Zimbabwe           175356           158            ASHANTI KUVIMBA
# Zimbabwe           175357           159           Munyurwa, Seraph
#
#                         Title    FIDE  Age  K-factor  Unnamed: 0_y    #  Flag  \
# Country
# Afghanistan                FM  1999.0   35        20           132  133   NaN
# Afghanistan  unranked/unrated  1871.0   49        20           132  133   NaN
# Afghanistan  unranked/unrated  1866.0   33        20           132  133   NaN
# Afghanistan  unranked/unrated  1846.0   19        20           132  133   NaN
# Afghanistan  unranked/unrated  1790.0   78        20           132  133   NaN
# ...                       ...     ...  ...       ...           ...  ...   ...
# Zimbabwe     unranked/unrated  1056.0   24        40            96   97   NaN
# Zimbabwe     unranked/unrated  1045.0   15        40            96   97   NaN
# Zimbabwe     unranked/unrated  1029.0   34        40            96   97   NaN
# Zimbabwe     unranked/unrated  1028.0   18        40            96   97   NaN
# Zimbabwe     unranked/unrated  1014.0   22        40            96   97   NaN
#
#              Num Players  Women  % of Women  FIDE Average  GMs  IMs  FMs  \
# Country
# Afghanistan           78      1        1.28          1650    0    0    5
# Afghanistan           78      1        1.28          1650    0    0    5
# Afghanistan           78      1        1.28          1650    0    0    5
# Afghanistan           78      1        1.28          1650    0    0    5
# Afghanistan           78      1        1.28          1650    0    0    5
# ...                  ...    ...         ...           ...  ...  ...  ...
# Zimbabwe             287     66       23.00          1617    0    4    0
# Zimbabwe             287     66       23.00          1617    0    4    0
# Zimbabwe             287     66       23.00          1617    0    4    0
# Zimbabwe             287     66       23.00          1617    0    4    0
# Zimbabwe             287     66       23.00          1617    0    4    0
#
#              WGMs  WIMs  WFMs  Age Avg
# Country
# Afghanistan     0     0     0       40
# Afghanistan     0     0     0       40
# Afghanistan     0     0     0       40
# Afghanistan     0     0     0       40
# Afghanistan     0     0     0       40
# ...           ...   ...   ...      ...
# Zimbabwe        0     0     0       25
# Zimbabwe        0     0     0       25
# Zimbabwe        0     0     0       25
# Zimbabwe        0     0     0       25
# Zimbabwe        0     0     0       25
#
# [175381 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175381 entries, Afghanistan to Zimbabwe
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0_x  175381 non-null  int64
#  1   Country Rank  175381 non-null  int64
#  2   Name          175381 non-null  object
#  3   Title         175381 non-null  object
#  4   FIDE          175381 non-null  float64
#  5   Age           175381 non-null  int64
#  6   K-factor      175381 non-null  int64
#  7   Unnamed: 0_y  175381 non-null  int64
#  8   #             175381 non-null  int64
#  9   Flag          0 non-null       float64
#  10  Num Players   175381 non-null  int64
#  11  Women         175381 non-null  int64
#  12  % of Women    175381 non-null  float64
#  13  FIDE Average  175381 non-null  int64
#  14  GMs           175381 non-null  int64
#  15  IMs           175381 non-null  int64
#  16  FMs           175381 non-null  int64
#  17  WGMs          175381 non-null  int64
#  18  WIMs          175381 non-null  int64
#  19  WFMs          175381 non-null  int64
#  20  Age Avg       175381 non-null  int64
# dtypes: float64(3), int64(16), object(2)
# memory usage: 29.4+ MB

# %%
# dropping unamed and flag columns that contain no data or nan
df.drop([col for col in df.columns if "Unnamed" in col], axis=1, inplace=True)
df.drop([col for col in df.columns if "Flag" in col], axis=1, inplace=True)

# %%
df.head(20)
# Out:
#              Country Rank                       Name             Title  \
# Country
# Afghanistan             1      Mirzaad, S.wahabuddin                FM
# Afghanistan             2              Rahmani, Asef  unranked/unrated
# Afghanistan             3        Sarwari, Hamidullah  unranked/unrated
# Afghanistan             4          Sakhawaty, Sepehr  unranked/unrated
# Afghanistan             5  Jamshedy, Mohammad Ismail  unranked/unrated
# Afghanistan             6          Mohtaat, Homayoun  unranked/unrated
# Afghanistan             7         Badghisi, Jarullah  unranked/unrated
# Afghanistan             8            Amini Ezatullah  unranked/unrated
# Afghanistan             9         Yaqeen, Muizzuddin  unranked/unrated
# Afghanistan            10         Hosini, Abdulrahim  unranked/unrated
# Afghanistan            11           Samsoor M Shoaib  unranked/unrated
# Afghanistan            12     Shir Ahmad Wahab Zadah  unranked/unrated
# Afghanistan            13              Hamrah, Lidaa  unranked/unrated
# Albania                 1            Dervishi, Erald                GM
# Albania                 2              Ashiku, Franc                IM
# Albania                 3              Pasko, Llambi                IM
# Albania                 4            Mehmeti, Dritan                IM
# Albania                 5               Seitaj, Ilir                IM
# Albania                 6             Qendro, Llambi                IM
# Albania                 7           Petritaj, Fotjon  unranked/unrated
#
#                FIDE  Age  K-factor    #  Num Players  Women  % of Women  \
# Country
# Afghanistan  1999.0   35        20  133           78      1        1.28
# Afghanistan  1871.0   49        20  133           78      1        1.28
# Afghanistan  1866.0   33        20  133           78      1        1.28
# Afghanistan  1846.0   19        20  133           78      1        1.28
# Afghanistan  1790.0   78        20  133           78      1        1.28
# Afghanistan  1751.0   50        20  133           78      1        1.28
# Afghanistan  1693.0   24        40  133           78      1        1.28
# Afghanistan  1581.0   41        40  133           78      1        1.28
# Afghanistan  1536.0   42        20  133           78      1        1.28
# Afghanistan  1363.0   35        40  133           78      1        1.28
# Afghanistan  1312.0   33        40  133           78      1        1.28
# Afghanistan  1292.0   46        40  133           78      1        1.28
# Afghanistan  1284.0   25        40  133           78      1        1.28
# Albania      2511.0   43        10  106          234     17        7.26
# Albania      2428.0   29        10  106          234     17        7.26
# Albania      2413.0   31        10  106          234     17        7.26
# Albania      2382.0   44        10  106          234     17        7.26
# Albania      2340.0   65        10  106          234     17        7.26
# Albania      2299.0   69        10  106          234     17        7.26
# Albania      2244.0   40        20  106          234     17        7.26
#
#              FIDE Average  GMs  IMs  FMs  WGMs  WIMs  WFMs  Age Avg
# Country
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Afghanistan          1650    0    0    5     0     0     0       40
# Albania              1751    1    7    6     0     0     3       43
# Albania              1751    1    7    6     0     0     3       43
# Albania              1751    1    7    6     0     0     3       43
# Albania              1751    1    7    6     0     0     3       43
# Albania              1751    1    7    6     0     0     3       43
# Albania              1751    1    7    6     0     0     3       43
# Albania              1751    1    7    6     0     0     3       43

# %%
# seperating out non and numeric columns
cat_df = df.select_dtypes(include=['object'])
num_df = df.select_dtypes(exclude=['object'])

def printColumnTypes(non_numeric_df, numeric_df):
    '''separates non-numeric and numeric columns'''
    print("Non-Numeric columns:")
    for col in non_numeric_df:
        print(f"{col}")
    print("")
    print("Numeric columns:")
    for col in numeric_df:
        print(f"{col}")
        
printColumnTypes(cat_df, num_df)
# Out:
# Non-Numeric columns:
# Name
# Title
#
# Numeric columns:
# Country Rank
# FIDE
# Age
# K-factor
# #
# Num Players
# Women
# % of Women
# FIDE Average
# GMs
# IMs
# FMs
# WGMs
# WIMs
# WFMs
# Age Avg

# %%
# % of values missing in each column
values_list = list()
cols_list = list()
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())*100
    cols_list.append(col)
    values_list.append(pct_missing)
pct_missing_df = pd.DataFrame()
pct_missing_df['col'] = cols_list
pct_missing_df['pct_missing'] = values_list
pct_missing_df
# Out:
#              col  pct_missing
# 0   Country Rank          0.0
# 1           Name          0.0
# 2          Title          0.0
# 3           FIDE          0.0
# 4            Age          0.0
# 5       K-factor          0.0
# 6              #          0.0
# 7    Num Players          0.0
# 8          Women          0.0
# 9     % of Women          0.0
# 10  FIDE Average          0.0
# 11           GMs          0.0
# 12           IMs          0.0
# 13           FMs          0.0
# 14          WGMs          0.0
# 15          WIMs          0.0
# 16          WFMs          0.0
# 17       Age Avg          0.0

# %% [markdown]
# - No missing values in the data set after dropping those columns

# %%
def summarize_df(df):
    print('-----Head-------')
    print(df.head(3))
    print('-----shape------')
    print('{} rows and {} columns'.format(df.shape[0], df.shape[1]))
    print('---info---')
    print(df.info())
    print(df.describe())
    print('----Catagorical Variables----')
    print(df.select_dtypes(include='object').columns.tolist())
    print('----Continous  Variables----')
    print(df.select_dtypes(exclude='object').columns.tolist())
    print('--nulls--')
    num_cols = [col for col in df.columns if df[col].dtype != 'O']
    cat_cols = [col for col in df.columns if col not in num_cols]
    print('=====================================================')
    for col in df.columns:
        if col in cat_cols:
            print(df[col].value_counts())
        else:
            print(df[col].value_counts(bins=10, sort=False))
    print('=====================================================')
    df = df.replace(r'^\s*$', np.NaN, regex=True)
    print(df.isna().sum())

# %%
summarize_df(df)
# Out:
# -----Head-------
#              Country Rank                   Name             Title    FIDE  \
# Country
# Afghanistan             1  Mirzaad, S.wahabuddin                FM  1999.0
# Afghanistan             2          Rahmani, Asef  unranked/unrated  1871.0
# Afghanistan             3    Sarwari, Hamidullah  unranked/unrated  1866.0
#
#              Age  K-factor    #  Num Players  Women  % of Women  FIDE Average  \
# Country
# Afghanistan   35        20  133           78      1        1.28          1650
# Afghanistan   49        20  133           78      1        1.28          1650
# Afghanistan   33        20  133           78      1        1.28          1650
#
#              GMs  IMs  FMs  WGMs  WIMs  WFMs  Age Avg
# Country
# Afghanistan    0    0    5     0     0     0       40
# Afghanistan    0    0    5     0     0     0       40
# Afghanistan    0    0    5     0     0     0       40
# -----shape------
# 175381 rows and 18 columns
# ---info---
# <class 'pandas.core.frame.DataFrame'>
# Index: 175381 entries, Afghanistan to Zimbabwe
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Country Rank  175381 non-null  int64
#  1   Name          175381 non-null  object
#  2   Title         175381 non-null  object
#  3   FIDE          175381 non-null  float64
#  4   Age           175381 non-null  int64
#  5   K-factor      175381 non-null  int64
#  6   #             175381 non-null  int64
#  7   Num Players   175381 non-null  int64
#  8   Women         175381 non-null  int64
#  9   % of Women    175381 non-null  float64
#  10  FIDE Average  175381 non-null  int64
#  11  GMs           175381 non-null  int64
#  12  IMs           175381 non-null  int64
#  13  FMs           175381 non-null  int64
#  14  WGMs          175381 non-null  int64
#  15  WIMs          175381 non-null  int64
#  16  WFMs          175381 non-null  int64
#  17  Age Avg       175381 non-null  int64
# dtypes: float64(2), int64(14), object(2)
# memory usage: 25.4+ MB
# None
#         Country Rank           FIDE            Age      K-factor  \
# count  175381.000000  175381.000000  175381.000000  175381.00000
# mean     3220.720107    1559.102912      36.373621      29.53983
# std      3779.465491     386.580746      20.447049      10.32867
# min         1.000000    1001.000000       6.000000      10.00000
# 25%       483.000000    1222.000000      18.000000      20.00000
# 50%      1653.000000    1554.000000      31.000000      20.00000
# 75%      4598.000000    1859.000000      53.000000      40.00000
# max     16673.000000    2864.100000     970.000000      40.00000
#
#                    #    Num Players          Women     % of Women  \
# count  175381.000000  175381.000000  175381.000000  175381.000000
# mean       21.133806   13019.435041    1313.018320      10.260135
# std        26.014522   11959.747166    1567.664315       5.416396
# min         1.000000       6.000000       0.000000       0.000000
# 25%         4.000000    3252.000000     211.000000       5.890000
# 50%        10.000000    8008.000000     625.000000       9.010000
# 75%        28.000000   25009.000000    1751.000000      13.880000
# max       185.000000   34497.000000    5734.000000      37.500000
#
#         FIDE Average            GMs            IMs            FMs  \
# count  175381.000000  175381.000000  175381.000000  175381.000000
# mean     1614.633717      50.872666     117.256784     265.832525
# std       164.338670      60.307850     135.488938     331.988731
# min      1141.000000       0.000000       0.000000       0.000000
# 25%      1469.000000      12.000000      27.000000      65.000000
# 50%      1627.000000      36.000000      81.000000     144.000000
# 75%      1720.000000      55.000000     134.000000     328.000000
# max      1961.000000     236.000000     522.000000    1177.000000
#
#                 WGMs           WIMs           WFMs        Age Avg
# count  175381.000000  175381.000000  175381.000000  175381.000000
# mean        8.455580      21.261944      53.701296      38.718852
# std        13.177731      26.181265     105.302666       7.646048
# min         0.000000       0.000000       0.000000      21.000000
# 25%         1.000000       4.000000      10.000000      34.000000
# 50%         4.000000      14.000000      21.000000      41.000000
# 75%         9.000000      30.000000      37.000000      44.000000
# max        50.000000     101.000000     409.000000      63.000000
# ----Catagorical Variables----
# ['Name', 'Title']
# ----Continous  Variables----
# ['Country Rank', 'FIDE', 'Age', 'K-factor', '#', 'Num Players', 'Women', '% of Women', 'FIDE Average', 'GMs', 'IMs', 'FMs', 'WGMs', 'WIMs', 'WFMs', 'Age Avg']
# --nulls--
# =====================================================
# (-15.673, 1668.2]     88123
# (1668.2, 3335.4]      32302
# (3335.4, 5002.6]      14345
# (5002.6, 6669.8]      10209
# (6669.8, 8337.0]       8340
# (8337.0, 10004.2]      7063
# (10004.2, 11671.4]     5148
# (11671.4, 13338.6]     5001
# (13338.6, 15005.8]     3182
# (15005.8, 16673.0]     1668
# Name: Country Rank, dtype: int64
# Horvath, Laszlo            7
# Kiss, Laszlo               6
# Ivanova, Anna              5
# Fiala, Jan                 5
# Mueller, Michael           5
#                           ..
# Zemtsovskaya, Ekaterina    1
# Ucles Lirola, Angela       1
# Khomenko, Ljubov           1
# Reales, Dario              1
# Praggnanandhaa R           1
# Name: Name, Length: 174070, dtype: int64
# unranked/unrated    162521
# FM                    4368
# IM                    2356
# WFM                   1776
# GM                    1312
# CM                    1115
# WIM                    835
# WCM                    775
# WGM                    322
# WH                       1
# Name: Title, dtype: int64
# (999.136, 1187.31]    39420
# (1187.31, 1373.62]    23674
# (1373.62, 1559.93]    25350
# (1559.93, 1746.24]    27061
# (1746.24, 1932.55]    25668
# (1932.55, 2118.86]    20217
# (2118.86, 2305.17]     9897
# (2305.17, 2491.48]     3321
# (2491.48, 2677.79]      714
# (2677.79, 2864.1]        59
# Name: FIDE, dtype: int64
# (5.034999999999999, 102.4]    175368
# (102.4, 198.8]                    10
# (198.8, 295.2]                     0
# (295.2, 391.6]                     1
# (391.6, 488.0]                     0
# (488.0, 584.4]                     0
# (584.4, 680.8]                     0
# (680.8, 777.2]                     0
# (777.2, 873.6]                     1
# (873.6, 970.0]                     1
# Name: Age, dtype: int64
# (9.969000000000001, 13.0]     4029
# (13.0, 16.0]                     1
# (16.0, 19.0]                     0
# (19.0, 22.0]                 85681
# (22.0, 25.0]                     0
# (25.0, 28.0]                     0
# (28.0, 31.0]                     0
# (31.0, 34.0]                     0
# (34.0, 37.0]                     0
# (37.0, 40.0]                 85670
# Name: K-factor, dtype: int64
# (0.815, 19.4]     112514
# (19.4, 37.8]       31921
# (37.8, 56.2]       13989
# (56.2, 74.6]        6856
# (74.6, 93.0]        4863
# (93.0, 111.4]       2507
# (111.4, 129.8]      1726
# (129.8, 148.2]       598
# (148.2, 166.6]       318
# (166.6, 185.0]        89
# Name: #, dtype: int64
# (-28.492, 3455.1]     50355
# (3455.1, 6904.2]      37212
# (6904.2, 10353.3]     17937
# (10353.3, 13802.4]     6130
# (13802.4, 17251.5]        0
# (17251.5, 20700.6]        0
# (20700.6, 24149.7]    14363
# (24149.7, 27598.8]    26824
# (27598.8, 31047.9]        0
# (31047.9, 34497.0]    22560
# Name: Num Players, dtype: int64
# (-5.735, 573.4]     78116
# (573.4, 1146.8]     27388
# (1146.8, 1720.2]    22803
# (1720.2, 2293.6]    24514
# (2293.6, 2867.0]        0
# (2867.0, 3440.4]        0
# (3440.4, 4013.8]     8732
# (4013.8, 4587.2]        0
# (4587.2, 5160.6]        0
# (5160.6, 5734.0]    13828
# Name: Women, dtype: int64
# (-0.0385, 3.75]     3780
# (3.75, 7.5]        67642
# (7.5, 11.25]       48579
# (11.25, 15.0]      20292
# (15.0, 18.75]      25555
# (18.75, 22.5]       3899
# (22.5, 26.25]       3394
# (26.25, 30.0]       1378
# (30.0, 33.75]        196
# (33.75, 37.5]        666
# Name: % of Women, dtype: int64
# (1140.179, 1223.0]      217
# (1223.0, 1305.0]      11078
# (1305.0, 1387.0]       4339
# (1387.0, 1469.0]      28817
# (1469.0, 1551.0]       5886
# (1551.0, 1633.0]      39378
# (1633.0, 1715.0]      37736
# (1715.0, 1797.0]      21821
# (1797.0, 1879.0]      19203
# (1879.0, 1961.0]       6906
# Name: FIDE Average, dtype: int64
# (-0.237, 23.6]    74360
# (23.6, 47.2]      24424
# (47.2, 70.8]      47502
# (70.8, 94.4]      12126
# (94.4, 118.0]      3141
# (118.0, 141.6]        0
# (141.6, 165.2]        0
# (165.2, 188.8]        0
# (188.8, 212.4]        0
# (212.4, 236.0]    13828
# Name: GMs, dtype: int64
# (-0.523, 52.2]    71375
# (52.2, 104.4]     21888
# (104.4, 156.6]    56164
# (156.6, 208.8]     1975
# (208.8, 261.0]        0
# (261.0, 313.2]    10151
# (313.2, 365.4]        0
# (365.4, 417.6]        0
# (417.6, 469.8]        0
# (469.8, 522.0]    13828
# Name: IMs, dtype: int64
# (-1.178, 117.7]     80909
# (117.7, 235.4]      47381
# (235.4, 353.1]       6439
# (353.1, 470.8]      16673
# (470.8, 588.5]          0
# (588.5, 706.2]          0
# (706.2, 823.9]          0
# (823.9, 941.6]      10151
# (941.6, 1059.3]         0
# (1059.3, 1177.0]    13828
# Name: FMs, dtype: int64
# (-0.051000000000000004, 5.0]    113407
# (5.0, 10.0]                      27527
# (10.0, 15.0]                      7884
# (15.0, 20.0]                     12735
# (20.0, 25.0]                         0
# (25.0, 30.0]                         0
# (30.0, 35.0]                         0
# (35.0, 40.0]                         0
# (40.0, 45.0]                         0
# (45.0, 50.0]                     13828
# Name: WGMs, dtype: int64
# (-0.10200000000000001, 10.1]    70242
# (10.1, 20.2]                    57275
# (20.2, 30.3]                    10037
# (30.3, 40.4]                    15267
# (40.4, 50.5]                     8732
# (50.5, 60.6]                        0
# (60.6, 70.7]                        0
# (70.7, 80.8]                        0
# (80.8, 90.9]                        0
# (90.9, 101.0]                   13828
# Name: WIMs, dtype: int64
# (-0.41, 40.9]     138701
# (40.9, 81.8]       22852
# (81.8, 122.7]          0
# (122.7, 163.6]         0
# (163.6, 204.5]         0
# (204.5, 245.4]         0
# (245.4, 286.3]         0
# (286.3, 327.2]         0
# (327.2, 368.1]         0
# (368.1, 409.0]     13828
# Name: WFMs, dtype: int64
# (20.956999999999997, 25.2]     7460
# (25.2, 29.4]                  22043
# (29.4, 33.6]                  10705
# (33.6, 37.8]                  36160
# (37.8, 42.0]                  44927
# (42.0, 46.2]                  26352
# (46.2, 50.4]                  24797
# (50.4, 54.6]                     30
# (54.6, 58.8]                   2904
# (58.8, 63.0]                      3
# Name: Age Avg, dtype: int64
# =====================================================
# Country Rank    0
# Name            0
# Title           0
# FIDE            0
# Age             0
# K-factor        0
# #               0
# Num Players     0
# Women           0
# % of Women      0
# FIDE Average    0
# GMs             0
# IMs             0
# FMs             0
# WGMs            0
# WIMs            0
# WFMs            0
# Age Avg         0
# dtype: int64

# %%
def chess_split(df):
    #splitting our data
    train_validate, test = train_test_split(df, test_size=.2, 
                                        random_state=123, 
                                        stratify=df.GMs)
    train, validate = train_test_split(train_validate, test_size=.3, 
                                   random_state=123, 
                                   stratify=train_validate.GMs)
    return train, validate, test


def prep_chess(df):
    #cleaning and splitting our data
    train, validate, test = chess_split(df)
    return train, validate, test

# %%
train, validate, test = prep_chess(df)

# %%
def explore_univariate(df, variable):
    '''
    explore_univariate will take in a dataframe, and one feature or variable. It graphs a box plot and a distribution 
    of the single variable.
    '''
    #set figure size, font for axis ticks, and turns off gridlines.
    plt.figure(figsize=(30,10))
    sns.set(font_scale = 2)
    sns.set_style("whitegrid", {'axes.grid' : False})
    
    # boxplot
    plt.subplot(1, 2, 1)
    sns.boxplot(x=variable, data=df)
    plt.xlabel('')
    plt.title('Box Plot', fontsize=30)
    
    # distribution
    plt.subplot(1, 2, 2)
    sns.histplot(data=df, x=variable, element='step', kde=True, color='blue')
    plt.xlabel('')
    plt.ylabel('')
    plt.title('Distribution', fontsize=30)
    
    #title
    plt.suptitle(f'{variable}', fontsize = 45)
    plt.tight_layout()
    plt.show()

# %%
for i in train.columns:
    explore_univariate(train, i)
    print(f'Summary Statistics for {i}\n{train[i].describe()}')
# Out:
# Summary Statistics for Country Rank
# count    98212.000000
# mean      3224.443866
# std       3782.553332
# min          1.000000
# 25%        484.000000
# 50%       1652.000000
# 75%       4600.000000
# max      16673.000000
# Name: Country Rank, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-9818512ee887> in <module>
#       1 for i in train.columns:
# ----> 2     explore_univariate(train, i)
#       3     print(f'Summary Statistics for {i}\n{train[i].describe()}')
#
# <ipython-input-16-75994755ba60> in explore_univariate(df, variable)
#      11     # boxplot
#      12     plt.subplot(1, 2, 1)
# ---> 13     sns.boxplot(x=variable, data=df)
#      14     plt.xlabel('')
#      15     plt.title('Box Plot', fontsize=30)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in infer_orient(x, y, orient, require_numeric)
#    1319             warnings.warn(single_var_warning.format("Vertical", "x"))
#    1320         if require_numeric and x_type != "numeric":
# -> 1321             raise TypeError(nonnumeric_dv_error.format("Horizontal", "x"))
#    1322         return "h"
#    1323
#
# TypeError: Horizontal orientation requires numeric `x` variable.
